# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import cv2

# %%
df = pd.read_csv('Dataset/FullIJCNN2013/gt.txt', sep=';')
df['width'] = 1360
df['height'] = 800
df = df[['filename', 'width', 'height', 'class', 'xmin', 'ymin', 'xmax', 'ymax']]

# %%
df.head()
# Out:
#     filename  width  height  class  xmin  ymin  xmax  ymax
# 0  00000.ppm   1360     800     11   774   411   815   446
# 1  00001.ppm   1360     800     40   983   388  1024   432
# 2  00001.ppm   1360     800     38   386   494   442   552
# 3  00001.ppm   1360     800     13   973   335  1031   390
# 4  00002.ppm   1360     800     39   892   476  1006   592

# %%
df.to_csv('Dataset/FullIJCNN2013/labels.csv', index=False)

# %% [markdown]
# ### Test rectangle

# %%
plt.figure(figsize=(20, 8))
img = cv2.imread('Dataset/FullIJCNN2013/00000.ppm')
img = cv2.rectangle(img, (774, 411), (815, 446), (150, 250, 0), 3)
plt.imshow(img)
